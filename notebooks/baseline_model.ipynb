# %%
import pandas as pd

from src.data import X_train, y_train, X_test, y_test
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
import numpy as np

# %%
from src.feature_engineering import FeatureEngineering
models = [LogisticRegression(), DummyClassifier(strategy='most_frequent')]
for model in range(len(models)):
    if model not in [DummyClassifier(strategy='most_frequent')]:
        models[model] = make_pipeline(StandardScaler(), models[model])
    models[model].fit(X_train, y_train)

# %%
def precision_at_k(estimator, X, y, k=100):
    y_score = estimator.predict_proba(X)[:,1]
    y = np.asarray(y)

    top_k_idx = np.argsort(y_score)[::-1][:k]

    return y[top_k_idx].sum() / k

scores = []
for model in models:
    y_score = model.predict_proba(X_test)[:, 1]
    auc_score = roc_auc_score(y_test, y_score)
    precision_at_k_score = precision_at_k(model, X_test,y_test, 100)
    scores.append((model.steps, auc_score, precision_at_k_score))

# %%
scores.sort(key=lambda x:x[2], reverse=True)
scores
# Out:
# [([('standardscaler', StandardScaler()),
#    ('logisticregression', LogisticRegression())],
#   0.5137074991810422,
#   np.float64(0.24)),
#  ([('standardscaler', StandardScaler()),
#    ('dummyclassifier', DummyClassifier(strategy='most_frequent'))],
#   0.5,
#   np.float64(0.21))]

# %%
import pandas as pd
coef = pd.DataFrame({
    "feature": X_train.columns,
    "coefficient":models[0][1].coef_.ravel()
              })
coef = coef.sort_values("coefficient", ascending=False)
coef
# Out:
#                          feature  coefficient
# 1                         Tenure     0.030148
# 31          Work Location_Hybrid     0.029402
# 13                 Gender_Female     0.029387
# 3             Performance Rating     0.028399
# 12        Manager Feedback Score     0.020434
# 37        Work-Life Balance_Poor     0.017112
# 5                 Training Hours     0.014773
# 20       Marital Status_Divorced     0.014496
# 2                         Salary     0.013403
# 34     Work-Life Balance_Average     0.013128
# 11            Distance from Home     0.012683
# 32         Work Location_On-site     0.010729
# 4             Projects Completed     0.010305
# 27                 Department_HR     0.009136
# 18      Education Level_Master's     0.006903
# 23              Job Role_Analyst     0.006258
# 17   Education Level_High School     0.006189
# 0                            Age     0.004470
# 25              Job Role_Manager     0.002618
# 24            Job Role_Developer    -0.000105
# 30              Department_Sales    -0.000404
# 21        Marital Status_Married    -0.000418
# 8             Satisfaction Level    -0.002362
# 29          Department_Marketing    -0.003384
# 14                   Gender_Male    -0.004929
# 7                 Overtime Hours    -0.005052
# 28                 Department_IT    -0.005077
# 19           Education Level_PhD    -0.007039
# 16    Education Level_Bachelor's    -0.007718
# 22         Marital Status_Single    -0.008406
# 10                   Absenteeism    -0.008938
# 26                Job Role_Sales    -0.012907
# 35   Work-Life Balance_Excellent    -0.013422
# 36        Work-Life Balance_Good    -0.024108
# 6                     Promotions    -0.024865
# 33          Work Location_Remote    -0.030159
# 9   Average Monthly Hours Worked    -0.047633
# 15                  Gender_Other    -0.090123
