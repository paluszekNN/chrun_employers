# %%
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
import numpy as np
from src.data import X_train, y_train, X_test, y_test

from src.feature_engineering import FeatureEngineering

models = [RandomForestClassifier(),
          XGBClassifier()
          ]
for model in range(len(models)):
    models[model] = make_pipeline(FeatureEngineering(), StandardScaler(), models[model])
    models[model].fit(X_train, y_train)

# %%
y_test.mean()
# Out:
# np.float64(0.203)

# %%
def precision_at_k(estimator, X, y, k=100):
    y_score = estimator.predict_proba(X)
    y = np.asarray(y)
    top_k_idx = np.argsort(y_score[:, 1])[::-1][:k]
    return y[top_k_idx].sum() / k


scores = []
for model in models:
    y_score = model.predict(X_test)
    auc_score = roc_auc_score(y_test, y_score)
    precision_at_k_score = precision_at_k(model, X_test,y_test, 100)
    scores.append((model.steps, auc_score, precision_at_k_score))

# %%
scores.sort(key=lambda x: x[2], reverse=True)
scores
# Out:
# [([('featureengineering',
#     <src.feature_engineering.FeatureEngineering at 0x1d828a77790>),
#    ('standardscaler', StandardScaler()),
#    ('xgbclassifier',
#     XGBClassifier(base_score=None, booster=None, callbacks=None,
#                   colsample_bylevel=None, colsample_bynode=None,
#                   colsample_bytree=None, device=None, early_stopping_rounds=None,
#                   enable_categorical=False, eval_metric=None, feature_types=None,
#                   feature_weights=None, gamma=None, grow_policy=None,
#                   importance_type=None, interaction_constraints=None,
#                   learning_rate=None, max_bin=None, max_cat_threshold=None,
#                   max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#                   max_leaves=None, min_child_weight=None, missing=nan,
#                   monotone_constraints=None, multi_strategy=None, n_estimators=None,
#                   n_jobs=None, num_parallel_tree=None, ...))],
#   0.4994777212576719,
#   np.float64(0.22)),
#  ([('featureengineering',
#     <src.feature_engineering.FeatureEngineering at 0x1d821d611b0>),
#    ('standardscaler', StandardScaler()),
#    ('randomforestclassifier', RandomForestClassifier())],
#   0.5,
#   np.float64(0.18))]

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps=[('features', FeatureEngineering()),
    ('scaler', StandardScaler()),
    ('pca', 'passthrough'),
    ('model', LogisticRegression())])

grid =param_grid = [

    # ================= LINEAR (STOCHASTIC) =================
    {
        'pca': ['passthrough', PCA(n_components=10), PCA(n_components=30)],
        'model': [LogisticRegression(
    solver="saga",
    max_iter=2000,
    n_jobs=1,
    random_state=42)],
    "model__penalty": ["l1", "l2"],
    "model__C": [0.01, 0.1, 1, 10],
    "model__class_weight": [None, "balanced"]
    },

    {
        'scaler': ['passthrough'],
        'pca': ['passthrough'],
        'model': [RandomForestClassifier(
            random_state=42, n_estimators=300, n_jobs=1, class_weight="balanced"
        )],
        'model__max_depth': [None, 8, 12, 16],
        'model__min_samples_split': [2, 5, 10],
        'model__min_samples_leaf': [1, 5, 10, 20],
        'model__max_features': ["sqrt", 0.3, 0.5]
    },

    {
        'scaler': ['passthrough'],
        'pca': ['passthrough'],
        'model': [XGBClassifier(
        n_estimators=500,
        learning_rate=0.05,
        objective="binary:logistic",
        scale_pos_weight=0.2,
        eval_metric=precision_at_k,
        random_state=42,
        n_jobs=1
    )],
        'model__max_depth': [3, 4, 5, 6],
        'model__eta': [0.01, 0.1, 0.3],
        'model__min_child_weight': [1, 3, 5, 7],
        'model__subsample': [0.7, 0.8, 0.9],
        'model__colsample_bytree': [0.7, 0.8, 0.9],
        'model__gamma': [0, 0.5, 1],
        'model__reg_alpha': [1, 2, 5],
    }
]
cv = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)
grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring = {
    "auc": "roc_auc",
    "p_at_k": precision_at_k
    },
    refit='p_at_k',
    cv=cv,
    n_jobs=-4,
    verbose=3
)

grid.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 4080 candidates, totalling 12240 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('features',
#                                         <src.feature_engineering.FeatureEngineering object at 0x000001D828BA59F0>),
#                                        ('scaler', StandardScaler()),
#                                        ('pca', 'passthrough'),
#                                        ('model', LogisticRegression())]),
#              n_jobs=-4,
#              param_grid=[{'model': [LogisticRegression(max_iter=2000, n_jobs=1,
#                                                        random_sta...
#                           'model__colsample_bytree': [0.7, 0.8, 0.9],
#                           'model__eta': [0.01, 0.1, 0.3],
#                           'model__gamma': [0, 0.5, 1],
#                           'model__max_depth': [3, 4, 5, 6],
#                           'model__min_child_weight': [1, 3, 5, 7],
#                           'model__reg_alpha': [1, 2, 5],
#                           'model__subsample': [0.7, 0.8, 0.9],
#                           'pca': ['passthrough'], 'scaler': ['passthrough']}],
#              refit='p_at_k',
#              scoring={'auc': 'roc_auc',
#                       'p_at_k': <function precision_at_k at 0x000001D821D29990>},
#              verbose=3)

# %%
import pandas as pd
results = pd.DataFrame(grid.cv_results_)
results.sort_values("mean_test_p_at_k", ascending=False).iloc[0]
# Out:
# mean_fit_time                                                              1.069501
# std_fit_time                                                               0.002987
# mean_score_time                                                            0.088543
# std_score_time                                                             0.006291
# param_model                       XGBClassifier(base_score=None, booster=None, c...
# param_model__C                                                                  NaN
# param_model__class_weight                                                       NaN
# param_model__penalty                                                            NaN
# param_pca                                                               passthrough
# param_model__max_depth                                                            6
# param_model__max_features                                                       NaN
# param_model__min_samples_leaf                                                   NaN
# param_model__min_samples_split                                                  NaN
# param_scaler                                                            passthrough
# param_model__colsample_bytree                                                   0.9
# param_model__eta                                                               0.01
# param_model__gamma                                                              1.0
# param_model__min_child_weight                                                   7.0
# param_model__reg_alpha                                                          1.0
# param_model__subsample                                                          0.9
# params                            {'model': XGBClassifier(base_score=None, boost...
# split0_test_auc                                                            0.473681
# split1_test_auc                                                            0.478737
# split2_test_auc                                                            0.487321
# mean_test_auc                                                              0.479913
# std_test_auc                                                                0.00563
# rank_test_auc                                                                  1685
# split0_test_p_at_k                                                             0.19
# split1_test_p_at_k                                                             0.23
# split2_test_p_at_k                                                             0.31
# mean_test_p_at_k                                                           0.243333
# std_test_p_at_k                                                            0.049889
# rank_test_p_at_k                                                                  1
# Name: 3209, dtype: object

# %% [markdown]
# best tuned model:
#
# Pipeline(steps=[('features', FeatureEngineering()),
#     ('scaler', StandardScaler()),
#     ('pca', 'passthrough'),
#     ('model', XGBClassifier(
#         n_estimators=500,
#         learning_rate=0.05,
#         objective="binary:logistic",
#         scale_pos_weight=0.2,
#         eval_metric=precision_at_k,
#         random_state=42,
#         n_jobs=1,
#         max_depth=6
#         colsample_bytree=0.9,
#         eta=0.01,
#         gamma=1.0,
#         min_child_weight=7.0,
#         reg_alpha=1.0,
#         subsample=0.9
#     ))])

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.145575      0.008535         0.123679        0.051207
# 1       0.303169      0.011867         0.056849        0.002088
# 2       0.306232      0.046426         0.056133        0.001540
# 3       0.163940      0.028901         0.061734        0.007141
# 4       0.128743      0.032920         0.056154        0.002569
#
#                                          param_model  param_model__C  \
# 0  LogisticRegression(max_iter=2000, n_jobs=1, ra...            0.01
# 1  LogisticRegression(max_iter=2000, n_jobs=1, ra...            0.01
# 2  LogisticRegression(max_iter=2000, n_jobs=1, ra...            0.01
# 3  LogisticRegression(max_iter=2000, n_jobs=1, ra...            0.01
# 4  LogisticRegression(max_iter=2000, n_jobs=1, ra...            0.01
#
#   param_model__class_weight param_model__penalty             param_pca  \
# 0                      None                   l1           passthrough
# 1                      None                   l1  PCA(n_components=10)
# 2                      None                   l1  PCA(n_components=30)
# 3                      None                   l2           passthrough
# 4                      None                   l2  PCA(n_components=10)
#
#   param_model__max_depth  ... split2_test_auc  mean_test_auc  std_test_auc  \
# 0                    NaN  ...        0.500000       0.500000      0.000000
# 1                    NaN  ...        0.500000       0.500000      0.000000
# 2                    NaN  ...        0.500000       0.500000      0.000000
# 3                    NaN  ...        0.483521       0.483031      0.000978
# 4                    NaN  ...        0.499936       0.495227      0.005825
#
#   rank_test_auc  split0_test_p_at_k  split1_test_p_at_k  split2_test_p_at_k  \
# 0             2                0.23                0.19                0.19
# 1             2                0.23                0.19                0.19
# 2             2                0.23                0.19                0.19
# 3           991                0.11                0.12                0.18
# 4            77                0.18                0.22                0.18
#
#    mean_test_p_at_k  std_test_p_at_k  rank_test_p_at_k
# 0          0.203333         0.018856               217
# 1          0.203333         0.018856               217
# 2          0.203333         0.018856               217
# 3          0.136667         0.030912              4062
# 4          0.193333         0.018856               555
#
# [5 rows x 33 columns]
